# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=1.5)

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/brAIns 22년도 (1학기)/train.csv')
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/brAIns 22년도 (1학기)/test.csv')
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1
df_test['FamilySize'] = df_test['SibSp'] + df_train['Parch'] + 1

df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i>0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i>0 else 0) 

#저번 발표까지 했던 부분에 대한 데이터 편집
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# 3.1 Fill Null

# %%
#이름의 앞부분 추출

df_train['Initial'] = df_train.Name.str.extract('([A-Za-z]+)\.')
df_test['Initial'] = df_test.Name.str.extract('([A-Za-z]+)\.')

# %%
df_train['Initial']
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Initial, Length: 891, dtype: object

# %%
#추출된 이니셜의 성별에 따른 인원수 차이

pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_95dc8_row0_col0, #T_95dc8_row0_col1, #T_95dc8_row0_col3, #T_95dc8_row0_col4, #T_95dc8_row0_col5, #T_95dc8_row0_col7, #T_95dc8_row0_col8, #T_95dc8_row0_col12, #T_95dc8_row0_col15, #T_95dc8_row0_col16, #T_95dc8_row1_col2, #T_95dc8_row1_col6, #T_95dc8_row1_col9, #T_95dc8_row1_col10, #T_95dc8_row1_col11, #T_95dc8_row1_col13, #T_95dc8_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_95dc8_row0_col2, #T_95dc8_row0_col6, #T_95dc8_row0_col9, #T_95dc8_row0_col10, #T_95dc8_row0_col11, #T_95dc8_row0_col13, #T_95dc8_row0_col14, #T_95dc8_row1_col0, #T_95dc8_row1_col1, #T_95dc8_row1_col3, #T_95dc8_row1_col4, #T_95dc8_row1_col5, #T_95dc8_row1_col7, #T_95dc8_row1_col8, #T_95dc8_row1_col12, #T_95dc8_row1_col15, #T_95dc8_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_95dc8_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
#이니셜 카테고리 간소화

df_train['Initial'].replace(['Mlle', 'Mme','Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don', 'Dona'], 
                            ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr', 'Mr'], inplace=True)
df_test['Initial'].replace(['Mlle', 'Mme','Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don', 'Dona'], 
                            ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr', 'Mr'], inplace=True)

# %%
df_train['Initial']
# Out:
# 0         Mr
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4         Mr
#        ...
# 886    Other
# 887     Miss
# 888     Miss
# 889       Mr
# 890       Mr
# Name: Initial, Length: 891, dtype: object

# %%
df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Initial
# Master    414.975000  0.575000  2.625000   4.574167  2.300000  1.375000
# Miss      411.741935  0.704301  2.284946  21.860000  0.698925  0.537634
# Mr        455.880907  0.162571  2.381853  32.739609  0.293006  0.151229
# Mrs       456.393701  0.795276  1.984252  35.981818  0.692913  0.818898
# Other     564.444444  0.111111  1.666667  45.888889  0.111111  0.111111
#
#              Fare  FamilySize
# Initial
# Master   3.340710    4.675000
# Miss     3.123713    2.236559
# Mr       2.651507    1.444234
# Mrs      3.443751    2.511811
# Other    2.641605    1.222222

# %%
#이니셜 별로 생존 평균 도출

df_train.groupby('Initial')['Survived'].mean().plot.bar()

# %%
#공백으로 있던 연령을 평균값으로 채우기

df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'), 'Age'] = 33
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'), 'Age'] = 36
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'), 'Age'] = 5
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'), 'Age'] = 22
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'), 'Age'] = 46

df_test.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'), 'Age'] = 33
df_test.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'), 'Age'] = 36
df_test.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'), 'Age'] = 5
df_test.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'), 'Age'] = 22
df_test.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'), 'Age'] = 46

# %%
df_train.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    22.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#Embarked 또한 Null data의 개수 확인

print('Embarked has ', sum(df_train['Embarked'].isnull()), ' Null values')
# Out:
# Embarked has  2  Null values

# %%
#Null data를 가장 많은 Embarked 값이었던 S로 채우기

df_train['Embarked'].fillna('S', inplace=True)

# %% [markdown]
# 3.2 Change Age

# %%
#연령별로 실제 나이가 아닌 간소한 숫자로 카테고리화

df_train['Age_cat'] = 0
df_train.loc[df_train['Age'] < 10, 'Age_cat'] = 0
df_train.loc[(10 <= df_train['Age']) & (df_train['Age'] < 20), 'Age_cat'] = 1
df_train.loc[(20 <= df_train['Age']) & (df_train['Age'] < 30), 'Age_cat'] = 2
df_train.loc[(30 <= df_train['Age']) & (df_train['Age'] < 40), 'Age_cat'] = 3
df_train.loc[(40 <= df_train['Age']) & (df_train['Age'] < 50), 'Age_cat'] = 4
df_train.loc[(50 <= df_train['Age']) & (df_train['Age'] < 60), 'Age_cat'] = 5
df_train.loc[(60 <= df_train['Age']) & (df_train['Age'] < 70), 'Age_cat'] = 6
df_train.loc[70 <= df_train['Age'], 'Age_cat'] = 7

df_test['Age_cat'] = 0
df_test.loc[df_train['Age'] < 10, 'Age_cat'] = 0
df_test.loc[(10 <= df_test['Age']) & (df_test['Age'] < 20), 'Age_cat'] = 1
df_test.loc[(20 <= df_test['Age']) & (df_test['Age'] < 30), 'Age_cat'] = 2
df_test.loc[(30 <= df_test['Age']) & (df_test['Age'] < 40), 'Age_cat'] = 3
df_test.loc[(40 <= df_test['Age']) & (df_test['Age'] < 50), 'Age_cat'] = 4
df_test.loc[(50 <= df_test['Age']) & (df_test['Age'] < 60), 'Age_cat'] = 5
df_test.loc[(60 <= df_test['Age']) & (df_test['Age'] < 70), 'Age_cat'] = 6
df_test.loc[70 <= df_test['Age'], 'Age_cat'] = 7

# %%
#다른 방법

def category_age(x):
  if x < 10:
    return 0
  elif x < 20:
    return 1
  elif x < 30:
    return 2
  elif x < 40:
    return 3
  elif x < 50:
    return 4
  elif x < 60:
    return 5
  elif x <70:
    return 6
  else:
    return 7

df_train['Age_cat_2'] = df_train['Age'].apply(category_age)

# %%
print('1번 방법, 2번 방법 둘다 같은 결과를 내면 True 줘야함 -> ', (df_train['Age_cat'] == df_train['Age_cat_2']).all())
# Out:
# 1번 방법, 2번 방법 둘다 같은 결과를 내면 True 줘야함 ->  True

# %%
df_train.drop(['Age', 'Age_cat_2'], axis=1, inplace=True)
df_test.drop(['Age'], axis=1, inplace=True)

# %% [markdown]
# 3.3 Change Initial, Embarked and Sex (string to numerical)

# %%
#이름의 Initial 파트 또한 숫자로 카테고리화

df_train['Initial'] = df_train['Initial'].map({'Master' : 0, 'Miss' : 1, 'Mr' : 2, 'Mrs' : 3, 'Other' : 4})
df_test['Initial'] = df_test['Initial'].map({'Master' : 0, 'Miss' : 1, 'Mr': 2, 'Mrs' : 3, 'Other' : 4})

# %%
df_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df_train['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#Embarked 또한 문자 대신 숫자로 카테고리화

df_train['Embarked'] = df_train['Embarked'].map({'C' : 0, 'Q' : 1, 'S' : 2})
df_test['Embarked'] = df_test['Embarked'].map({'C' : 0, 'Q' : 1, 'S' : 2})

# %%
df_train['Embarked'].isnull().any()
# Out:
# False

# %%
#성별 또한 문자열 대신 숫자로 카테고리화

df_train['Sex'] = df_train['Sex'].map({'female' : 0, 'male' : 1})
df_test['Sex'] = df_test['Sex'].map({'female' : 0, 'male' : 1})

# %%
#상관관계 그래프로 각 요소간 상관관게의 정도 파악

heatmap_data = df_train[['Survived', 'Pclass', 'Sex', 'Fare', 'Embarked', 'FamilySize', 'Initial', 'Age_cat']]

colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size":16})

del heatmap_data

# %% [markdown]
# 3.4 One-hot encoding on Initial and Embarked

# %%
#One-hot encoding을 사용하기 위한 카테고리의 수만큼 Column수 증가

df_train = pd.get_dummies(df_train, columns=['Initial'], prefix='Initial')
df_test = pd.get_dummies(df_test, columns=['Initial'], prefix='Initial')

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#    SibSp  Parch   Ticket      Fare Cabin  Embarked  FamilySize  Age_cat  \
# 0      0      0   330911  2.057860   NaN         1         1.0        3
# 1      1      0   363272  1.945910   NaN         2         2.0        4
# 2      0      0   240276  2.270836   NaN         1         1.0        6
# 3      0      0   315154  2.159003   NaN         2         1.0        2
# 4      1      1  3101298  2.508582   NaN         2         2.0        2
#
#    Initial_0  Initial_1  Initial_2  Initial_3  Initial_4
# ...

# %%
df_train = pd.get_dummies(df_train, columns=['Embarked'], prefix='Embarked')
df_test = pd.get_dummies(df_test, columns=['Embarked'], prefix='Embarked')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0      1      0
# 2                             Heikkinen, Miss. Laina    0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0      1      0
# 4                           Allen, Mr. William Henry    1      0      0
#
#              Ticket      Fare Cabin  FamilySize  Age_cat  Initial_0  \
# 0         A/5 21171  1.981001   NaN           2        2          0
# 1          PC 17599  4.266662   C85           2        3          0
# 2  STON/O2. 3101282  2.070022   NaN           1        2          0
# ...

# %% [markdown]
# 3.5 Drop columns

# %%
#학습에 불필요한 데이터는 dataset에서 제거

df_train.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)
df_test.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df_test.head()
# Out:
#    Pclass  Sex      Fare  FamilySize  Age_cat  Initial_0  Initial_1  \
# 0       3    1  2.057860         1.0        3          0          0
# 1       3    0  1.945910         2.0        4          0          0
# 2       2    1  2.270836         1.0        6          0          0
# 3       3    1  2.159003         1.0        2          0          0
# 4       3    0  2.508582         2.0        2          0          0
#
#    Initial_2  Initial_3  Initial_4  Embarked_0  Embarked_1  Embarked_2
# 0          1          0          0           0           1           0
# 1          0          1          0           0           0           1
# 2          1          0          0           0           1           0
# 3          1          0          0           0           0           1
# 4          0          1          0           0           0           1

# %% [markdown]
# 4 Building machine learnign model and prediction using the trained model

# %%
#importing all the required ML packages
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# 4.1 Preparation - Split dataset into train, valid, test set

# %%
#Data set 나누기

X_train = df_train.drop('Survived', axis=1).values
target_label = df_train['Survived'].values
X_test = df_test.values

# %%
X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, target_label, test_size=0.3, random_state=2018)

# %% [markdown]
# 4.2 Model generation and prediction

# %%
#import한 라이브러리를 통해 학습 진행

model = RandomForestClassifier()
model.fit(X_tr, y_tr)
prediction = model.predict(X_vld)

# %%
print('총 {}명 wnd {:.2f}% 정확도로 생존을 맞춤'.format(y_vld.shape[0], 100*metrics.accuracy_score(prediction, y_vld)))
# Out:
# 총 268명 wnd 82.84% 정확도로 생존을 맞춤

# %% [markdown]
# 4.3 Feature importance

# %%
from pandas import Series

feature_importance = model.feature_importances_
Series_feat_imp = Series(feature_importance, index=df_test.columns)

# %%
plt.figure(figsize=(8,8))
Series_feat_imp.sort_values(ascending=True).plot.barh()
plt.xlabel('Feature importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# 4.4 Prediction on Test set

# %%
submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/brAIns 22년도 (1학기)/gender_submission.csv')

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
#생성한 학습모델을 가지고 test_set data에서 평가 진행

prediction = model.predict(X_test)
submission['Survived'] = prediction

# %%
submission.to_csv('./my_first_submission.csv', index=False)
